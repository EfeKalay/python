# %%
print('Yeşil başlı gövel ördek uçar gider göle karşı')
print("Eğricesin tel tel etmiş açar gider yele karşı")
# Out:
# Yeşil başlı gövel ördek uçar gider göle karşı
# Eğricesin tel tel etmiş açar gider yele karşı

# %%
f(x) = 2x + 3
y = f(5)
# Out:
#   File "<ipython-input-8-b2ddc4187878>", line 1
#     f(x) = 2x + 3
#             ^
# SyntaxError: invalid syntax

# %%
def f(x):
  return 2*x + 3
y = f(5)
print(y)
# Out:
# 13

# %%
x = 100
y = 123
z = x + y

# %%
2 = 10
1 = 01
3 = 11

# %%
#3 bit en küçük sayı = 000 = 0
#3 bit en büyük sayı = 111 = 7  ->  2^3 -1

# 8 bit en büyük sayi = 2^8 -1 = 255 = BYTE
2**8 -1

8GB = 8000 MB = 8000000 KB = 800000000000 B
# Out:
# 255

# %%
a = 100 # dynamic typed
type(a)
# Out:
# int

# %%
b = 2.5
type(b)
# Out:
# float

# %%
c = 'ahmet'
type
# Out:
# str
