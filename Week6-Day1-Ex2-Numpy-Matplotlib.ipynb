# %%
import numpy as np
import matplotlib.pyplot as plt
koordinatlar = np.loadtxt("points.txt",dtype="int",delimiter=",")
#print(koordinatlar)
x = koordinatlar[:,0]
y = koordinatlar[:,1]
plt.scatter(x,y)
plt.show()

# %%
araclar = ["Kamyon","Araba","Bisiklet"]
sayilari = [30,88,23]
plt.pie(sayilari,labels=araclar,explode=[0,0,0.1])
plt.show()

# %%
import matplotlib.pyplot as plt

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax = plt.subplots(1,2)
ax[0].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax[1].pie(sayilari,labels=araclar,explode=[0,0,0.1])
plt.show()

# %%
x = np.arange(0,100,1)
y = np.random.randint(50,size=100)

plt.plot(x,y)
plt.show()

# %%
def generateRandom():
    x = np.random.randint(10)
    y = np.random.randint(100,120)
    return (x,y)


a, b = generateRandom()

print(b)

b,c = 34,56

print(b)
# Out:
# 101
# 34
